# %% [markdown]
# <a href="https://colab.research.google.com/github/AllyanSystumm/Open-CV-Tasks/blob/main/OpenCV%20Python%20Real-Life%20Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
